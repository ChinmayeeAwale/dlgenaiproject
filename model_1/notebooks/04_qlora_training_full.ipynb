# %% [markdown]
# # 04 QLoRA Training Full\n
# Run full training using tuned pilot hyperparameters.

# %%
from pathlib import Path\n
import yaml\n
cfg = yaml.safe_load(Path('../configs/train_finance.yaml').read_text(encoding='utf-8'))\n
cfg

# %%
print('Use this notebook to run full Trainer loop and save best adapter to models/adapters/.')
