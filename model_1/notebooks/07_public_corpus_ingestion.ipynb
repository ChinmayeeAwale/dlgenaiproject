# %% [markdown]
# # 07 Public Corpus Ingestion\n
# Ingest public finance documents for RAG.

# %%
from pathlib import Path\n
corpus_dir = Path('../data/corpus')\n
corpus_dir.mkdir(parents=True, exist_ok=True)\n
print('Populate this directory with cleaned public documents.')
